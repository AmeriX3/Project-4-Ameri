# %%
import requests

# %% [markdown]
# # Get

# %%
r = requests.get("http://127.0.0.1:5000/data/all/sa").json()
r
# Out:
# {'reviewerName': {'0': 'Strider',
#   '1': 'The Nudnik',
#   '2': 'LaWanda',
#   '3': 'Kelly Joseph "kej718"""',
#   '4': 'K. Lai',
#   '5': 'Katy G.',
#   '6': 'Freddy M',
#   '7': 'Randy Poe',
#   '8': 'RASHAWN',
#   '9': 'Raul Orozco',
#   '10': 'queball4u',
#   '11': 'Ed Brunell',
#   '12': 'Dan-O',
#   '13': 'Dave Drury',
#   '14': 'Carlos E. Portillo "dreamer79"""',
#   '15': 'Danfzzl',
#   '16': 'Keith',
#   '17': 'S. Zimmerman',
#   '18': 'trlamb',
#   '19': 'T. Beaulieu',
#   '20': 'Scott Sanchez "Scott"""',
#   '21': 'P. Young "P"""',
#   '22': 'J_Onyx "I never let my schooling interfere wi..."',
#   '23': '...',
#   '24': 'Mason Smiley',
#   '25': 'B. C. Dunlap',
#   '26': 'Daniel Kowalec',
#   '27': 'Paul Hartley',
#   '28': 'Zimms',
#   '29': 'Travis Stock "DiamondGuy"""',
#   '30': 'starrroad',
#   '31': 'Stuck in Alaska',
#   '32': 'T.D. Donn',
#   '33': 'Amazon Customer "Kung-Fu master"""',
#   '34': 'Hakmin',
#   '35': 'K. Lewis',
#   '36': 'Judy C Jackson',
# ...

# %%
year=2022
r = requests.get(f"http://127.0.0.1:5000/data/{year}/sa").json()
r
# Out:
# {'reviewerName': {'0': 'Ameri', '1': 'Hassan', '2': 'Ameri'},
#  'reviewText': {'0': 'Take it or leave it', '1': 'Its ok', '2': 'good enough'},
#  'reviewTime': {'0': '2022-08-15', '1': '2022-08-15', '2': '2022-08-15'},
#  'sentiment_score': {'0': -0.0516, '1': 0.296, '2': 0.4404}}

# %% [markdown]
# # Post

# %%
data={"name":"Ameri","review":"good enough"}

# %%
requests.post("http://127.0.0.1:5000/post",data=data)
# Out:
# <Response [200]>
