# %%
# Turn database into an api
import plotly.io as pio
import pandas as pd
import string
# Databases
import sqlalchemy as alch
# Languages
import re
import spacy
import nltk 
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from wordcloud import WordCloud
from langdetect import detect
from textblob import TextBlob
nlp = spacy.load("en_core_web_sm")
# Visualization
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import dotenv
dotenv.load_dotenv()
import plotly.express as px
import requests
from src import cleaner
nlp.max_length= 1223510
nltk.download('vader_lexicon')
passw = os.getenv("pass_sql")
dbName = "amazon_reviews"
connectionData = f"mysql+pymysql://root:password@localhost/amazon"
engine = alch.create_engine(connectionData)
import statistics as st
import numpy as np
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\moham\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
requests = requests.get("http://127.0.0.1:5000")
requests
# Out:
# <Response [200]>

# %%
requests.

# %%
def get_everything ():

    query = (f"""SELECT *FROM amazon_reviews;""")
    df=pd.read_sql_query(query,con=engine)
    df = pd.DataFrame(df)
    return df

# %%
def req_everything():
    request = requests.get("http://127.0.0.1:5000/data").json()
    
    return request

# %%
def get_reviews():
    query = (f"""SELECT reviewText,helpful_yes,total_vote FROM amazon_reviews;""")
    df=pd.read_sql_query(query,con=engine)
    return df.to_dict(orient="reviewText")

# %%
def req_reviews():
    request = requests.get("http://127.0.0.1:5000/data/reviews").json()
    
    return request

# %%
df2 = get_everything()
type(df2["reviewTime"][1])
# Out:
# str

# %%
dit = cleaner.req_reviews()

dit
df= pd.DataFrame.from_dict(dit)
ditt= df.to_json()
ditt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [65], in <cell line: 3>()
#       1 dit = cleaner.req_reviews()
# ----> 3 dit.to_json()
#       4 df= pd.DataFrame.from_dict(dit)
#       5 ditt= df.to_json()
#
# AttributeError: 'list' object has no attribute 'to_json'

# %%
df = get_everything()
df
# Out:
#           reviewerID        asin  reviewerName helpful  \
# 0     A3SBTW3WS4IQSN  B007WTAJTO                [0, 0]
# 1     A18K1ODH1I2MVB  B007WTAJTO          0mie  [0, 0]
# 2     A2FII3I2MBMUIA  B007WTAJTO           1K3  [0, 0]
# 3      A3H99DFEG68SR  B007WTAJTO           1m2  [0, 0]
# 4     A375ZM4U047O79  B007WTAJTO  2&amp;1/2Men  [0, 0]
# ...              ...         ...           ...     ...
# 4828  A2LBMKXRM5H2W9  B007WTAJTO      ZM "J"""  [0, 0]
# 4829   ALGDLRUI1ZPCS  B007WTAJTO            Zo  [0, 0]
# 4830  A2MR1NI0ENW2AD  B007WTAJTO     Z S Liske  [0, 0]
# 4831  A37E6P3DSO9QJD  B007WTAJTO      Z Taylor  [0, 0]
# 4832   A8KGFTFQ86IBR  B007WTAJTO           Zza  [0, 0]
#
#                                              reviewText  overall  \
# 0                                            No issues.      4.0
# 1     Purchased this for my device, it worked as adv...      5.0
# 2     it works as expected. I should have sprung for...      4.0
# ...

# %% [markdown]
# ## Sentiment Analysis

# %%
stop = nlp.Defaults.stop_words

# %%
new_list = []
for i in df["reviewText"]:
    i.split(" ")
    if i not in stop:
        new_list.append(i)
string_without_stop = " ".join(new_list)

# %%
sia = SentimentIntensityAnalyzer()

# %%
def sa (x):
    try:
        return sia.polarity_scores(x)
    except:
        return x

# %%
df2 = df["reviewText"].apply(sa) 
df2
# Out:
# 0       {'neg': 0.688, 'neu': 0.312, 'pos': 0.0, 'comp...
# 1       {'neg': 0.075, 'neu': 0.925, 'pos': 0.0, 'comp...
# 2       {'neg': 0.077, 'neu': 0.923, 'pos': 0.0, 'comp...
# 3       {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'comp...
# 4       {'neg': 0.038, 'neu': 0.835, 'pos': 0.127, 'co...
#                               ...
# 4828    {'neg': 0.091, 'neu': 0.817, 'pos': 0.092, 'co...
# 4829    {'neg': 0.0, 'neu': 0.939, 'pos': 0.061, 'comp...
# 4830    {'neg': 0.0, 'neu': 0.828, 'pos': 0.172, 'comp...
# 4831    {'neg': 0.0, 'neu': 0.802, 'pos': 0.198, 'comp...
# 4832    {'neg': 0.049, 'neu': 0.693, 'pos': 0.258, 'co...
# Name: reviewText, Length: 4833, dtype: object

# %%
alist = df["reviewText"].apply(sa)
lis=[]
for i in alist:
    lis.append(i["compound"])
df["sentiment_score"]= lis
df

# %%
df["sentiment_score"]= lis
df
# Out:
#           reviewerID        asin  reviewerName helpful  \
# 0     A3SBTW3WS4IQSN  B007WTAJTO                [0, 0]
# 1     A18K1ODH1I2MVB  B007WTAJTO          0mie  [0, 0]
# 2     A2FII3I2MBMUIA  B007WTAJTO           1K3  [0, 0]
# 3      A3H99DFEG68SR  B007WTAJTO           1m2  [0, 0]
# 4     A375ZM4U047O79  B007WTAJTO  2&amp;1/2Men  [0, 0]
# ...              ...         ...           ...     ...
# 4828  A2LBMKXRM5H2W9  B007WTAJTO      ZM "J"""  [0, 0]
# 4829   ALGDLRUI1ZPCS  B007WTAJTO            Zo  [0, 0]
# 4830  A2MR1NI0ENW2AD  B007WTAJTO     Z S Liske  [0, 0]
# 4831  A37E6P3DSO9QJD  B007WTAJTO      Z Taylor  [0, 0]
# 4832   A8KGFTFQ86IBR  B007WTAJTO           Zza  [0, 0]
#
#                                              reviewText  overall  \
# 0                                            No issues.      4.0
# 1     Purchased this for my device, it worked as adv...      5.0
# 2     it works as expected. I should have sprung for...      4.0
# ...

# %%
mask = np.array(Image.open(r'sdc.jpg'))

# %%
from PIL import Image

# %%
text = " ".join(i for i in df["reviewText"])
wordcloud = WordCloud(width=1600, height=800).generate(text)
plt.figure( figsize=(200,100) )
plt.imshow(wordcloud)
plt.axis("off")

plt.imshow(wordcloud)

# %%
li=[]
for i in alist:
    li.append(i["compound"])
st.mean(li)
# Out:
# 0.41386271466997726

# %%
df["sentiment_score"][1]["compound"]
# Out:
# -0.296

# %%
lis=[]
for i in df["sentiment_score"]:
    lis.append(i["compound"])
lis
# Out:
# [-0.296,
#  -0.296,
#  -0.3089,
#  0.7081,
#  0.7087,
#  0.0,
#  0.8992,
#  0.7768,
#  -0.296,
#  0.9167,
#  0.9258,
#  0.0,
#  0.0,
#  0.7425,
#  0.4295,
#  0.6239,
#  0.8316,
#  0.715,
#  0.9101,
#  -0.5574,
#  -0.1531,
#  0.644,
#  0.9097,
#  0.7772,
#  -0.1027,
#  0.2023,
#  0.4404,
#  -0.3365,
#  0.8687,
#  0.0,
#  0.8684,
#  0.9371,
#  0.5255,
#  0.9153,
#  -0.8895,
#  0.0,
#  -0.3477,
#  0.8402,
#  0.9452,
#  0.8344,
#  0.7845,
#  0.5182,
#  0.7876,
#  -0.4492,
#  0.8779,
#  0.4588,
#  -0.3291,
#  0.5233,
#  -0.1531,
#  0.6249,
#  0.8555,
#  0.7351,
#  0.4139,
#  0.9537,
#  0.8968,
#  0.1531,
#  0.6239,
#  -0.3576,
#  0.836,
#  -0.1181,
#  -0.0112,
#  0.4993,
#  0.8716,
#  -0.6956,
#  0.0,
#  0.2247,
#  0.8835,
#  0.0,
#  -0.6523,
#  0.9584,
#  -0.8083,
#  0.0,
#  0.7847,
#  0.0,
#  0.3775,
#  0.8316,
#  0.128,
#  0.222,
#  0.2325,
#  0.7784,
#  0.6319,
#  0.4404,
#  0.8294,
#  -0.7823,
#  0.807,
#  0.7003,
#  -0.29,
#  0.3523,
#  -0.4215,
#  -0.1725,
#  0.9523,
#  0.3391,
# ...

# %%
fig = px.histogram(data_frame=df, x=lis)
fig.show()
plt
# Out:
# <div>                            <div id="c2c136e0-13cd-4d2d-9519-fb373e570d36" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2c136e0-13cd-4d2d-9519-fb373e570d36")) {                    Plotly.newPlot(                        "c2c136e0-13cd-4d2d-9519-fb373e570d36",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"x=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[-0.296,-0.296,-0.3089,0.7081,0.7087,0.0,0.8992,0.7768,-0.296,0.9167,0.9258,0.0,0.0,0.7425,0.4295,0.6239,0.8316,0.715,0.9101,-0.5574,-0.1531,0.644,0.9097,0.7772,-0.1027,0.2023,0.4404,-0.3365,0.8687,0.0,0.8684,0.9371,0.5255,0.9153,-0.889
# ...

# %%
fig = px.violin(data_frame=df,x="reviewTime",y=lis)
fig.show()
# Out:
# <div>                            <div id="131aa1d3-ba3d-477d-bb84-f6f787ed3b14" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("131aa1d3-ba3d-477d-bb84-f6f787ed3b14")) {                    Plotly.newPlot(                        "131aa1d3-ba3d-477d-bb84-f6f787ed3b14",                        [{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"reviewTime=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","offsetgroup":"","orientation":"v","scalegroup":"True","showlegend":false,"x":["2014-07-23","2013-10-25","2012-12-23","2013-11-21","2013-07-13","2013-04-29","2013-10-19","2014-10-07","2014-03-24","2013-11-10","2013-11-05","2013-11-20","2014-04-07","2013-11-21","2014-02-17","2013-04-01","2014-02-03","20
# ...

# %%
pwd
# Out:
# 'C:\\Users\\moham\\OneDrive\\Desktop\\Project-4-Ameri'

# %%
dic
